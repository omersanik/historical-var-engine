# %%
import yfinance as yf
import numpy as np 
import pandas as pd
# Out:
# Running cells with 'Python' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/omersanik/.local/bin/python3.14 -m pip install ipykernel -U --user --force-reinstall'
